# %% [markdown]
# <a href="https://colab.research.google.com/github/mcornejocl/AT_TF/blob/main/01_corregir_bbdd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importar librerías
import pandas as pd

# %%
# Disponer URL GitHub con los datos
url = 'https://raw.githubusercontent.com/mcornejocl/AT_TF/main/twitter_racism_parsed_dataset.csv'

# Leer datos desde URL
twitter_data = pd.read_csv(url, quotechar='"').drop(columns = ['id', 'index', "Annotation"])
twitter_data.columns = ['text', 'label']
twitter_data.head(25)
# Out:
#                                                  text  label
# 0   @AAlwuhaib1977 Muslim mob violence against Hin...      1
# 1              @Te4m_NiGhtM4Re http://t.co/5Ih7MkDbQG      0
# 2   @jncatron @isra_jourisra @AMPalestine Islamoph...      1
# 3   Finally I'm all caught up, and that sudden dea...      0
# 4              @carolinesinders @herecomesfran *hugs*      0
# 5   Please, PLEASE start using "is your discernmen...      0
# 6   @aymannathem As soon as ISIS chased all the mi...      0
# 7   @Ali_Gharib @MaxBlumenthal Glad you like it. h...      0
# 8   @HuffPostRelig Islam invaded and conquered 2/3...      1
# 9   @semzyxx Do you approve of your pedophile prop...      1
# 10  @watan71969 @geeky_zekey Problem with vile Mus...      1
# 11  @Skawtnyc @athenahollow @twoscooters i don't t...      0
# 12  @dylanw that's cool. next time when a woman ta...      0
# 13  RT @hadi_elis: Erdogan's Egyptian Nightmare \n...      0
# ...

# %%
twitter_data['longitud'] = twitter_data['text'].str.len()

# %%
twitter_data = twitter_data[twitter_data['longitud']>60]

# %%
# Seleccionar 200 filas aleatorias
muestra_aleatoria = twitter_data.sample(n=200, random_state=42)

# Guardar los resultados en un csv
muestra_aleatoria[['text']].to_csv('muestra_racism_dataset.csv',index=False)

# Imprimir los resultados
print("Muestra de 200 filas aleatorias:")
muestra_aleatoria
# Out:
# Muestra de 200 filas aleatorias:
#                                                     text  label  longitud
# 5186   IT IS NOT A BLOCK BOT IT IS A TOOL TO SHARE BL...      0       140
# 4178   @JM_Yturralde No, they showed you the good fac...      1        91
# 8488   @LifeInKhilafah You could repeat that, but you...      0        95
# 12491  @noshirtkurt_ Have you ever had a period? No? ...      0        68
# 7957   add a filter to toggle showing phone-verified ...      0        98
# ...                                                  ...    ...       ...
# 745    @Col_Connaughton Muslims train babies to hate ...      1       110
# 2164   @dankmtl Hard to get stupider than you. Still ...      1        99
# 930    Not strategic; just being an A*hole. Calling i...      0        87
# 3838   @_d_n_verg_ @stevesalaita Palestinians are hal...      1       135
# 11879  @the_moth_reborn :P hopefully you didn't get s...      0        72
#
# [200 rows x 3 columns]

# %%
# Calcular el porcentaje de cada label
label_counts = muestra_aleatoria['label'].value_counts(normalize=True) * 100
label_counts
# Out:
# 0    82.5
# 1    17.5
# Name: label, dtype: float64

# %%
# Seleccionar 25 filas aleatorias
muestra_aleatoria_25 = twitter_data.sample(n=25, random_state=42)

# Guardar los resultados en un csv
muestra_aleatoria_25[['text']].to_csv('muestra_aleatoria_25.csv',index=False)

# Imprimir los resultados
print("Muestra de 25 filas aleatorias:")
muestra_aleatoria_25
# Out:
# Muestra de 25 filas aleatorias:
#                                                     text  label  longitud
# 5186   IT IS NOT A BLOCK BOT IT IS A TOOL TO SHARE BL...      0       140
# 4178   @JM_Yturralde No, they showed you the good fac...      1        91
# 8488   @LifeInKhilafah You could repeat that, but you...      0        95
# 12491  @noshirtkurt_ Have you ever had a period? No? ...      0        68
# 7957   add a filter to toggle showing phone-verified ...      0        98
# 2256   And I GUARANTEE you the same people who jacked...      0       138
# 10737  @NewEraJihadi @ShamiAnalyst You seem to have a...      0       111
# 13061  But I guess you're not really sure how to reac...      0       136
# 967    @CTVToronto These campaigns are all lies that ...      1       139
# 8422   Trapped in a pole-dancing venue with that hotc...      0        89
# 9900   @MaxBlumenthal @MaerRoshan And let's not forge...      0       133
# ...

# %%
# Calcular el porcentaje de cada label
label_counts = muestra_aleatoria['label'].value_counts(normalize=True) * 100
label_counts
